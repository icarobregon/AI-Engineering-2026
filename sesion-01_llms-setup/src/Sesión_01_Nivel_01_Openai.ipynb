# %% [markdown]
# <a href="https://colab.research.google.com/github/icarobregon/AI-Engineering-2026/blob/master/sesion-01_llms-setup/src/Sesi%C3%B3n_01_Nivel_01_Openai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.32.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-nano",
    input="Quiero alojar un proyecto personal desarrollado en Next.js y que necesita una base de datos PostgreSQL. Recomiéndame como hacerlo."
)

print(response.output_text)
# Out:
# Claro. La forma más práctica (y común) de alojar un proyecto Next.js con PostgreSQL es usar **un hosting para el front/back de Next** + **un servicio gestionado de Postgres**. Te dejo varias opciones (de más simple a más flexible) y qué elegir según tu caso.
#
# ## Opción A (recomendada por simplicidad): Next.js en Vercel + PostgreSQL gestionado
# **Ideal** si tu app no necesita mucha infraestructura propia.
#
# - **Next.js**: **Vercel** (auto-build, SSR/SSG, endpoints serverless, etc.)
# - **PostgreSQL**: **Supabase** (muy fácil) o **Neon** (también excelente) o **Railway**
#
# **Pros**
# - Setup rápido
# - Postgres gestionado (backup, alta disponibilidad, escalado básico)
# - Menos mantenimiento
#
# **Contras**
# - Si usas conexiones masivas/alta concurrencia, hay que cuidar el pool de conexiones (muy típico con Vercel + Postgres).
#
# ### Recomendaciones técnicas
# - Usa un **ORM** como **Prisma** o **Drizzle** con **pooling**.
# - Para evitar problemas de conexiones:
#   - En Next, usa configuración tipo `connection pooling` (p. ej. Prisma con adaptadores/limitación).
#   - O usa una plataforma de Postgres que ofrezca “pooler” (Neon/Supabase suelen ayudar en esto, según el plan).
#
# ---
#
# ## Opción B (muy buena para control): Next.js en tu VPS + PostgreSQL (managed o en Docker)
# **Ideal** si quieres control de infraestructura.
#
# Arquitectura típica:
# - **VPS** (DigitalOcean / AWS Lightsail / Hetzner / etc.)
# - **Docker** para:
#   - app Next (con build/producción)
#   - PostgreSQL (contenedor) o Postgres gestionado aparte
#
# **Pros**
# - Control total
# - Puedes ajustar red, puertos, volúmenes, backups
#
# **Contras**
# - Más mantenimiento: backups, actualizaciones de Postgres, seguridad.
#
# ### Recomendación si vas por Docker
# - Usa **volúmenes persistentes** para Postgres.
# - Configura **backups** (por ejemplo cron con `pg_dump`/`pg_dumpall`).
# - Pon **variables de entorno** para credenciales (`DATABASE_URL`).
# - Asegura acceso (solo desde tu app / firewall / security groups).
#
# ---
#
# ## Opción C (Kubernetes / cloud más “serio”): Next + Postgres en AWS/GCP/Azure
# **Ideal** si el proyecto crece o quieres estandarizar con infraestructura cloud.
#
# - Next.js en:
#   - **AWS Elastic Beanstalk**, **ECS**, **Lambda** (según patrón)
# - PostgreSQL en:
#   - **RDS** (AWS) / **Cloud SQL** (GCP) / **Azure Database for PostgreSQL**
#
# **Pros**
# - Escalabilidad y robustez
# - Gestión madura de servicios
#
# **Contras**
# - Más complejidad y coste de configuración
#
# ---
#
# # ¿Qué te recomiendo para un proyecto personal?
# Si es un proyecto personal o MVP y quieres salir rápido:
# ✅ **Vercel + Supabase o Neon**
# - Muy fácil
# - Buen rendimiento
# - Postgres gestionado
# - Menos cosas que mantener
#
# ---
#
# ## Pasos generales (independientemente de la opción)
# 1. **Conecta PostgreSQL**
#    - Define `DATABASE_URL` en variables de entorno.
# 2. **Agrega ORM / esquema**
#    - Ej. Prisma:
#      - `prisma init`
#      - define schema
#      - `prisma migrate dev`
# 3. **Configura Next para producción**
#    - Asegura que el servidor usa la URL correcta.
# 4. **Deploy**
#    - Subes el repo
#    - Vinculas variables de entorno
# 5. **Revisa pooling / conexiones**
#    - Si ves errores tipo “too many connections”, ajusta pooling o usa el pooler del proveedor.
#
# ---
#
# ## Para recomendarte la opción exacta necesito 3 datos
# 1) ¿Tu Next.js usa **App Router (app/)** o **Pages Router (pages/)**?
# 2) ¿Usas **Prisma** / otro ORM o consultas SQL “a mano”?
# 3) ¿Tu app tendrá tráfico pequeño/medio (personal) o esperas mucha concurrencia?
#
# Si me respondes eso, te digo cuál opción encaja mejor y te paso un ejemplo concreto de configuración (incluyendo variables de entorno y el patrón de conexión).
