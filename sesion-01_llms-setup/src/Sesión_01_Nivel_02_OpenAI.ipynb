# %% [markdown]
# <a href="https://colab.research.google.com/github/icarobregon/AI-Engineering-2026/blob/master/sesion-01_llms-setup/src/Sesi%C3%B3n_01_Nivel_02_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.32.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-nano",
    input="Actua como un Devops Senior de una empresa de desarrollo de software. Quiero alojar un proyecto personal desarrollado en Next.js y que necesita una base de datos PostgreSQL. Recomiéndame como hacerlo."
)

print(response.output_text)
# Out:
# Perfecto. Te recomiendo una arquitectura simple, segura y barata para un proyecto personal en Next.js con PostgreSQL, usando Docker (ideal para Dev personal) y desplegando con un PaaS o en un VPS.
#
# A continuación te dejo 3 opciones (de más simple a más flexible) y una recomendación final.
#
# ---
#
# ## Opción A (recomendada): Docker + un PaaS (Render / Railway / Fly.io)
# **Pros:** rápido de poner en marcha, menos mantenimiento.
# **Contras:** a veces cuesta un poco más que VPS y el networking puede requerir un ajuste.
#
# ### Cómo montarlo
# 1. **App Next.js en un servicio**
# 2. **PostgreSQL como servicio administrado** (normalmente el PaaS te lo provee)
# 3. Conectar por **variables de entorno**:
#    - `DATABASE_URL=postgresql://user:pass@host:5432/db?sslmode=require`
#
# ### Buenas prácticas
# - Usa `DATABASE_URL` desde el runtime (no “hardcodear”).
# - Activa **migraciones** (por ejemplo con Prisma) en el deploy.
#
# **Ejemplo de flujo:**
# - Pipeline:
#   - Build Next.js
#   - Ejecutar `prisma migrate deploy` (o equivalent)
#   - Levantar app
#
# ---
#
# ## Opción B: VPS (DigitalOcean / Hetzner / AWS Lightsail) + Docker Compose
# **Pros:** control total, barato a escala personal.
# **Contras:** tú administras actualizaciones/operación de infraestructura.
#
# ### Estructura típica
# - Un servidor con:
#   - `docker-compose.yml`
#   - Servicio `next-app`
#   - Servicio `postgres` (persistente con volumen)
#   - (opcional) `nginx` o reverse proxy + TLS (Let’s Encrypt)
#
# ### Ejemplo de `docker-compose.yml` (esqueleto)
# ```yaml
# services:
#   db:
#     image: postgres:16
#     environment:
#       POSTGRES_USER: app
#       POSTGRES_PASSWORD: "${POSTGRES_PASSWORD}"
#       POSTGRES_DB: appdb
#     volumes:
#       - pgdata:/var/lib/postgresql/data
#     ports:
#       - "5432:5432"
#
#   app:
#     build: .
#     environment:
#       DATABASE_URL: "postgresql://app:${POSTGRES_PASSWORD}@db:5432/appdb?sslmode=disable"
#     depends_on:
#       - db
#     ports:
#       - "3000:3000"
#
# volumes:
#   pgdata:
# ```
#
# Luego usarías un reverse proxy (por ejemplo Nginx) para que el sitio esté en `https://tu-dominio` con certificados.
#
# ### Buenas prácticas en VPS
# - **No expongas PostgreSQL a internet** si no es necesario. Ideal: dejarlo solo en la red interna Docker.
# - Usa secretos en un gestor (o al menos `.env` con permisos correctos).
# - Backups:
#   - `pg_dump` programado o snapshots del volumen.
# - Actualiza contenedores y dependencias.
#
# ---
#
# ## Opción C: Fly.io / similar con Postgres gestionado + app contenedorizada
# **Pros:** muy buena experiencia con Docker; despliegue rápido.
# **Contras:** puede tener detalles de networking diferentes.
#
# Generalmente funciona como:
# - App en un “machine”
# - Postgres gestionado o en otra app
# - Conexión por `DATABASE_URL` similar.
#
# ---
#
# # Mi recomendación para un proyecto personal
# ### Si quieres “hacerlo y olvidarte”:
# ✅ **Opción A**: Next.js + **PostgreSQL administrado** en un PaaS (Render/Railway/Fly).
# Es la forma más rápida y con menos dolores operativos.
#
# ### Si quieres control y coste mínimo:
# ✅ **Opción B**: VPS + **Docker Compose** (y Postgres en contenedor con volumen persistente), y Nginx con TLS.
#
# ---
#
# ## Checklist técnico (importante)
# 1. **ORM/migraciones**
#    - Si usas Prisma: `prisma migrate deploy` en el deploy.
# 2. **Persistencia de datos**
#    - En PaaS: el servicio de DB es gestionado.
#    - En VPS: volumen `pgdata`.
# 3. **Secretos**
#    - `DATABASE_URL`, credenciales, `JWT_SECRET`, etc.
# 4. **Backups**
#    - Programado y probado (restauración al menos una vez).
# 5. **Seguridad**
#    - Restringir acceso a DB
#    - Usar TLS cuando corresponda (depende si DB es administrada o no).
# 6. **Health checks**
#    - Para que el deploy/rollbacks no se queden “a medias”.
#
# ---
#
# ## Preguntas para afinarte la mejor solución
# 1. ¿Tienes **Prisma** u otro ORM? ¿O usas SQL “a mano”?
# 2. ¿El proyecto usa **Next.js con App Router** y qué framework de despliegue quieres: Node server, Docker, serverless?
# 3. ¿Presupuesto aproximado/mes? (ej: 0–10€, 10–30€, etc.)
# 4. ¿Tienes preferencia por proveedor (DigitalOcean, AWS, GCP, no importa)?
# 5. ¿Necesitas subida/entrega por GitHub (CI/CD) automática?
#
# Si me respondes eso, te propongo un plan concreto con:
# - arquitectura exacta,
# - variables de entorno,
# - configuración de migraciones,
# - y un ejemplo listo para desplegar (Render/Railway o Docker Compose en VPS).
