# %% [markdown]
# <a href="https://colab.research.google.com/github/icarobregon/AI-Engineering-2026/blob/master/sesion-01_llms-setup/src/Sesi%C3%B3n_01_Nivel_02_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.32.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-nano",
    instructions="Actua como un Devops Senior de una empresa de desarrollo de software. Responde de una manera técnica y directa.",
    input="Quiero alojar un proyecto personal desarrollado en Next.js y que necesita una base de datos PostgreSQL. Recomiéndame como hacerlo."
)

print(response.output_text)
# Out:
# Puedes alojarlo de forma bastante estándar con **Next.js + PostgreSQL** usando un PaaS para el backend de DB y, para el front, un runtime tipo Vercel/Render/Fly. Te dejo 3 opciones (de más simple a más control) y recomendaciones concretas.
#
# ---
#
# ## Opción A (simple, muy recomendada): **Render**
# **Qué cubre:** Web (Next.js) + PostgreSQL administrado + variables de entorno.
#
# **Cómo hacerlo:**
# 1. **Crear un PostgreSQL en Render**
#    - Dashboard → **New** → **PostgreSQL**
#    - Nombre del servicio, elige región
#    - Render te da un **`DATABASE_URL`** (o similar).
#
# 2. **Crear el servicio Web (Next.js)**
#    - Dashboard → **New** → **Web Service**
#    - Conectar tu repo de GitHub
#    - Comando de build típico Next:
#      - `Build command`: `npm run build` (o `yarn build` / `pnpm build`)
#      - `Start command`: `npm run start`
#        (Render puede inferir; si usas Next standard con `next start`, funciona.)
#
# 3. **Configurar variables de entorno**
#    - Agrega `DATABASE_URL` al servicio Web (tomándolo del servicio Postgres).
#    - Si usas Prisma, también:
#      - `DATABASE_URL`
#    - Para seguridad:
#      - No hardcodear credenciales en el repo.
#
# 4. **Migraciones**
#    - Si usas **Prisma**:
#      - Ejecuta migraciones antes de arrancar.
#    - En Render tienes dos enfoques:
#      - A) comando de build/start que ejecute `prisma migrate deploy` antes de iniciar
#      - B) crear un **botón/“worker”** o un “job” que ejecute migraciones
#
# **Ventajas:** rápido, infraestructura manejada, bajo mantenimiento.
#
# ---
#
# ## Opción B (robusta y muy usada): **Fly.io**
# **Qué cubre:** Puedes desplegar Next.js y PostgreSQL en el mismo ecosistema, con control de recursos y redes.
#
# **Cómo hacerlo:**
# 1. Configura proyecto con **Dockerfile** (recomendado).
# 2. Crea un **app** para Next.js.
# 3. Crea una instancia **postgres** en Fly (o usa imagen/volume).
# 4. Configura **secrets** en Fly (ej. `DATABASE_URL`).
# 5. Para migraciones:
#    - Ejecuta `prisma migrate deploy` en un paso previo (release command o “one-off job”).
#
# **Ventajas:** más control que Render, buena conectividad y performance.
#
# ---
#
# ## Opción C (estándar enterprise/infra): **VPS + Docker Compose**
# **Qué cubre:** Tú administras el servidor, pero el stack queda bien controlado.
#
# **Ejemplo típico:**
# - `docker-compose.yml` con:
#   - `postgres`
#   - `next` (contenedor con tu build)
# - Volúmenes persistentes para Postgres
# - Secrets por variables de entorno
# - Reverse proxy con **nginx** o trae el suyo según tu arquitectura
#
# **Ventajas:** máximo control y costo optimizable.
# **Desventajas:** mantenimiento (backups, updates, hardening, monitoreo).
#
# ---
#
# # Recomendaciones técnicas para Next.js + Postgres
# Independientemente de la plataforma:
#
# 1. **Usa un ORM con migraciones**
#    - Prisma es una opción común.
#    - Ejecuta migraciones en deploy (no manual siempre).
#
# 2. **No uses credenciales en el código**
#    - Todo vía `DATABASE_URL` en variables de entorno.
#
# 3. **Considera conexión y pooling**
#    - En serverless (p.ej. Vercel) hay que cuidar conexiones.
#    - Si tu hosting hace “autoscaling” fuerte, usa:
#      - **Prisma + PgBouncer** (según proveedor) o un pooler gestionado.
#
# 4. **Backups**
#    - Si el proveedor no gestiona backups, automatízalos (dump o snapshots).
#
# 5. **Variables y entornos**
#    - Separa `dev/staging/prod` (o al menos staging + prod).
#    - Activa logs y alertas básicas.
#
# ---
#
# ## ¿Cuál te recomiendo?
# - **Si quieres algo rápido y con mínimo mantenimiento:** **Render (Opción A)**.
# - **Si quieres control y buenas redes sin tanta fricción:** **Fly.io (Opción B)**.
# - **Si necesitas control total y no te importa operar infra:** **Docker/VPS (Opción C)**.
#
# ---
#
# ## Para afinarte una guía paso a paso
# Dime:
# 1. ¿Usas **Prisma** u otro ORM?
# 2. ¿Tu Next.js es **App Router** o **Pages Router**?
# 3. ¿Tienes preferencia por **Render / Fly / Vercel** o “cualquiera”?
# 4. ¿Tu proyecto usa **Server Actions / API routes** para acceder a la BD?
#
# Con eso te paso un setup concreto (build/start + migraciones + configuración de `DATABASE_URL`).
